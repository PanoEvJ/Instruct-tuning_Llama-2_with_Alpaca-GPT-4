# %% [markdown]
# <a href="https://colab.research.google.com/github/PanoEvJ/Instruct-tuning_Llama-2_with_Alpaca-GPT-4/blob/main/Finetune_LLaMA_with_Alpaca_GPT_4_Data_(5K_Samples)_Flash_Attention_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Technologies Used
#
# In this notebook we'll be taking advantage of the follow technologies, it's a long list - I know.
#
# - [Flash Attention](https://arxiv.org/abs/2205.14135)
# - LoRA
#   - [LoRA Paper](https://arxiv.org/abs/2106.09685)
#   - [HF's `peft` library](https://github.com/huggingface/peft)
# - HF's `transformers` library
# - `torch`
# - `cuda`
# - 4-bit Quantization (and Double-Quantization) from Tim Dettmers.
#   - [QLoRA Paper](https://arxiv.org/abs/2305.14314)
#   - `bitsandbytes`
# - `SFTTrainer`
#   - [TRL Library](https://github.com/lvwerra/trl)
# - HF's `datasets`
# - HF's `huggingface_hub`
#
# As you can see, we're relying on a number of amazing libraries, frameworks, and more.
#
# It's absolutely incredible what is possible these days!

# %% [markdown]
# ### Dependencies
#
# First things first, let's grab some dependencies.

# %%
# !pip install -U -q "transformers==4.31.0" "datasets==2.13.0" "peft==0.4.0" "accelerate==0.21.0" "bitsandbytes==0.40.2" "trl==0.4.7" "safetensors>=0.3.1"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 49.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 94.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.0 MB/s eta 0:00:00

# %% [markdown]
# ### Data
#
# Now, we'll load some of the GPT-4 generated Alpaca-GPT dataset.
#
# You can use essentially any data you'd like here - though I'd recommend leveraging some kind of instruction dataset.

# %%
from datasets import load_dataset

alpaca_gpt_4_dataset = load_dataset("c-s-ale/alpaca-gpt4-data", split="train")
# Out:
# Downloading readme:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/c-s-ale___json/c-s-ale--alpaca-gpt4-data-35876470b5e8cc77/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/43.4M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/52002 [00:00<?, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/c-s-ale___json/c-s-ale--alpaca-gpt4-data-35876470b5e8cc77/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.

# %%
len(alpaca_gpt_4_dataset)
# Out:
# 52002

# %% [markdown]
# We're going to do some naive filtering and sampling in order to allow the notebook to run in a reasonable amount of time (~1hr.)

# %%
dataset = alpaca_gpt_4_dataset.filter(lambda example: (len(example["input"]) + len(example["output"]) + len(example["instruction"])) <= 2000)
# Out:
# Filter:   0%|          | 0/52002 [00:00<?, ? examples/s]

# %%
len(dataset)
# Out:
# 49406

# %%
dataset = dataset.select(range(5_000))

# %%
len(dataset)
# Out:
# 5000

# %% [markdown]
# As always, we'll need to move our data into an instruction-prompt.
#
# There are many different approaches to this specific step, and you should feel free to modify and experiment here!

# %%
def format_row_as_instruction_prompt(example):
    primer_prompt_with_input = f"Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request."
    primer_prompt_no_input = f"Below is an instruction that describes a task. Write a response that appropriately completes the request."
    instruction_template = f"Provided an instruction and a input, please provide a coherent response. \n### Instruction:\n{example['instruction']}"
    input_template = f"### Input:\n{example['input']}"
    response_template = f"### Response:\n{example['output']}"

    total_prompt_list = []

    if example["input"]:
        total_prompt_list.append(primer_prompt_with_input)
        total_prompt_list.append(input_template)
    else:
        total_prompt_list.append(primer_prompt_no_input)

    total_prompt_list.append(response_template)

    return "\n\n".join(total_prompt_list)

# %% [markdown]
# Let's just confirm the format is as we expect:

# %%
print(format_row_as_instruction_prompt(alpaca_gpt_4_dataset[17]))
# Out:
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Input:
# def factorialize(num):
#   factorial = 1
#   for i in range(1, num):
#     factorial *= i
#
#   return factorial
#
# ### Response:
# Here is a new version of the code that calculates the factorial of a number using recursion:
#
# def factorial(num):
#     if num == 0:
#         return 1
#     else:
#         return num * factorial(num-1)

# %% [markdown]
# We'll leverage a helpful utility from Phil Schmid's [repo](https://github.com/philschmid/deep-learning-pytorch-huggingface/blob/main/training/utils/llama_patch.py)
#
# (taken from his helpful walkthrough [here](https://www.philschmid.de/instruction-tune-llama-2))
#
# NOTE: It will take a decent amount of time to install Flash Attention - please be patient!

# %%
# !pip install -q ninja packaging
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 2.7 MB/s eta 0:00:00

# %%
# !MAX_JOBS=4 pip install -U flash-attn --no-build-isolation
# Out:
# Collecting flash-attn
#   Downloading flash_attn-2.1.1.tar.gz (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.0.1+cu118)
# Collecting einops (from flash-attn)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash-attn) (23.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from flash-attn) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->flash-attn) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->flash-attn) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash-attn) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash-attn) (1.3.0)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.1.1-cp310-cp310-linux_x86_64.whl size=128602002 sha256=5c1e36839383a503761a4b97fc40898ebe4ec016547091daa5a8fd787ad342d4
#   Stored in directory: /root/.cache/pip/wheels/27/66/ed/1ca5cd61374c9d9352fd9d49c3f0ea740e36ec6ab508b31b55
# Successfully built flash-attn
# Installing collected packages: einops, flash-attn
# Successfully installed einops-0.6.1 flash-attn-2.1.1

# %%
# !git clone https://github.com/philschmid/deep-learning-pytorch-huggingface.git
# Out:
# Cloning into 'deep-learning-pytorch-huggingface'...
# remote: Enumerating objects: 409, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 409 (delta 107), reused 109 (delta 68), pack-reused 235
# Receiving objects: 100% (409/409), 707.31 KiB | 23.58 MiB/s, done.
# Resolving deltas: 100% (210/210), done.

# %%
# %cd deep-learning-pytorch-huggingface/training/
# Out:
# /content/deep-learning-pytorch-huggingface/training

# %% [markdown]
# ### Training Preparation
#
# Now we're ready to start setting up our configuration options!
#
# We're going to do the following preparation work:
#
# 1. If desired: Set-up FlashAttention through Phil's utility function.
# 2. Create our BitsAndBytesConfig for 4bit training.
# 3. Set up our LoRA config to leverage PEFT-LoRA

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

use_flash = True
use_flash_attention = None

if use_flash:
    if torch.cuda.get_device_capability()[0] >= 8:
        from utils.llama_patch import replace_attn_with_flash_attn
        print("Flashing That Attention")
        replace_attn_with_flash_attn()
        use_flash_attention = True

model_id = "NousResearch/Llama-2-7b-hf"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    use_cache=False,
    device_map="auto"
)

model.config.pretraining_tp = 1

if use_flash_attention:
    from utils.llama_patch import forward
    assert model.model.layers[0].self_attn.forward.__doc__ == forward.__doc__, "Model didn't Flash Attention"

tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Flashing That Attention
# Downloading (…)lve/main/config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
from peft import LoraConfig, prepare_model_for_kbit_training, get_peft_model

peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=32,
    bias="none",
    task_type="CAUSAL_LM"
)

model = prepare_model_for_kbit_training(model)

# %% [markdown]
# ### Training
#
# Now that we have all that out of the way, let's set up our `TrainingArguments`, since `SFTTRainer` extends the base HF `Trainer`, we can use familiar args. for this step!
#
# You'll notice that the values for `per_device_train_batch_size` are very low - this is largely due to Colab constraints. You could leverage a dedicate cloud instance provider if you were seeking to do some more serious fine-tuning/instruct-tuning.

# %%
from transformers import TrainingArguments

args = TrainingArguments(
    output_dir="llama_7_nf4_alpaca_gpt4",
    num_train_epochs=3,
    per_device_train_batch_size=4 if use_flash_attention else 1,
    gradient_accumulation_steps=2,
    gradient_checkpointing=True,
    optim="paged_adamw_32bit",
    logging_steps=1,
    save_strategy="steps",
    save_steps=100,
    learning_rate=2e-4,
    bf16=True,
    tf32=True,
    fp16=False,
    max_grad_norm=0.3,
    warmup_ratio=0.03,
    lr_scheduler_type="constant",
    disable_tqdm=True
)

if use_flash_attention:
    from utils.llama_patch import upcast_layer_for_flash_attention
    torch_dtype = torch.bfloat16 if args.bf16 else torch.float16 if args.fp16 else torch.float32
    model = upcast_layer_for_flash_attention(model, torch_dtype)

model = get_peft_model(model, peft_config)

# %% [markdown]
# Now we can set up our `SFTTrainer`!
#
# You'll notice that we provide the dataset - but we do not indicate labels/masks for our inputs - this is because behind the scenes, SFTTrainer is going to construct a new dataset for us (as well as efficiently packing that dataset).
#
# You could certainly take a number of approaches here, but for now we'll stick to the basics!

# %%
from trl import SFTTrainer

max_seq_len = 2048

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length=max_seq_len,
    tokenizer=tokenizer,
    packing=True,
    formatting_func=format_row_as_instruction_prompt,
    args=args,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/utils.py:246: UserWarning: The passed formatting_func has more than one argument. Usually that function should have a single argument `example` which corresponds to the dictonnary returned by each element of the dataset. Make sure you know what you are doing.
#   warnings.warn(

# %% [markdown]
# Nothing left to do but train!

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 1.3502, 'learning_rate': 0.0002, 'epoch': 0.0}
# {'loss': 1.3928, 'learning_rate': 0.0002, 'epoch': 0.0}
# {'loss': 1.3546, 'learning_rate': 0.0002, 'epoch': 0.0}
# {'loss': 1.2254, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 1.1259, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 1.155, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 1.1902, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 1.1, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 1.0895, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 1.1228, 'learning_rate': 0.0002, 'epoch': 0.02}
# {'loss': 1.1187, 'learning_rate': 0.0002, 'epoch': 0.02}
# {'loss': 1.107, 'learning_rate': 0.0002, 'epoch': 0.02}
# {'loss': 1.0975, 'learning_rate': 0.0002, 'epoch': 0.02}
# {'loss': 1.0911, 'learning_rate': 0.0002, 'epoch': 0.02}
# {'loss': 1.0056, 'learning_rate': 0.0002, 'epoch': 0.02}
# {'loss': 1.0721, 'learning_rate': 0.0002, 'epoch': 0.03}
# {'loss': 1.0282, 'learning_rate': 0.0002, 'epoch': 0.03}
# {'loss': 1.0159, 'learning_rate': 0.0002, 'epoch': 0.03}
# {'loss': 1.0463, 'learning_rate': 0.0002, 'epoch': 0.03}
# {'loss': 0.9452, 'learning_rate': 0.0002, 'epoch': 0.03}
# {'loss': 1.0004, 'learning_rate': 0.0002, 'epoch': 0.03}
# {'loss': 1.0104, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 1.0061, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 0.922, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 0.9616, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 0.9575, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 0.9712, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 0.9718, 'learning_rate': 0.0002, 'epoch': 0.04}
# {'loss': 0.9535, 'learning_rate': 0.0002, 'epoch': 0.05}
# {'loss': 0.9374, 'learning_rate': 0.0002, 'epoch': 0.05}
# {'loss': 0.9766, 'learning_rate': 0.0002, 'epoch': 0.05}
# {'loss': 0.925, 'learning_rate': 0.0002, 'epoch': 0.05}
# {'loss': 0.9479, 'learning_rate': 0.0002, 'epoch': 0.05}
# {'loss': 0.8965, 'learning_rate': 0.0002, 'epoch': 0.05}
# {'loss': 0.9779, 'learning_rate': 0.0002, 'epoch': 0.06}
# {'loss': 0.9247, 'learning_rate': 0.0002, 'epoch': 0.06}
# {'loss': 0.9344, 'learning_rate': 0.0002, 'epoch': 0.06}
# {'loss': 0.9245, 'learning_rate': 0.0002, 'epoch': 0.06}
# {'loss': 0.9506, 'learning_rate': 0.0002, 'epoch': 0.06}
# {'loss': 0.931, 'learning_rate': 0.0002, 'epoch': 0.06}
# {'loss': 0.9734, 'learning_rate': 0.0002, 'epoch': 0.07}
# {'loss': 0.9489, 'learning_rate': 0.0002, 'epoch': 0.07}
# {'loss': 0.9457, 'learning_rate': 0.0002, 'epoch': 0.07}
# {'loss': 0.8935, 'learning_rate': 0.0002, 'epoch': 0.07}
# {'loss': 0.9146, 'learning_rate': 0.0002, 'epoch': 0.07}
# {'loss': 0.9566, 'learning_rate': 0.0002, 'epoch': 0.07}
# {'loss': 0.8997, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.9597, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.8974, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.9132, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.9015, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.9265, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.9359, 'learning_rate': 0.0002, 'epoch': 0.08}
# {'loss': 0.9578, 'learning_rate': 0.0002, 'epoch': 0.09}
# {'loss': 0.9048, 'learning_rate': 0.0002, 'epoch': 0.09}
# {'loss': 0.9237, 'learning_rate': 0.0002, 'epoch': 1.0}
# {'loss': 0.9459, 'learning_rate': 0.0002, 'epoch': 1.0}
# {'loss': 0.8863, 'learning_rate': 0.0002, 'epoch': 1.0}
# {'loss': 0.9308, 'learning_rate': 0.0002, 'epoch': 1.01}
# {'loss': 0.8993, 'learning_rate': 0.0002, 'epoch': 1.01}
# {'loss': 0.9063, 'learning_rate': 0.0002, 'epoch': 1.01}
# {'loss': 0.9346, 'learning_rate': 0.0002, 'epoch': 1.01}
# {'loss': 0.8438, 'learning_rate': 0.0002, 'epoch': 1.01}
# {'loss': 0.895, 'learning_rate': 0.0002, 'epoch': 1.01}
# {'loss': 0.878, 'learning_rate': 0.0002, 'epoch': 1.02}
# {'loss': 0.9306, 'learning_rate': 0.0002, 'epoch': 1.02}
# {'loss': 0.9455, 'learning_rate': 0.0002, 'epoch': 1.02}
# {'loss': 0.9151, 'learning_rate': 0.0002, 'epoch': 1.02}
# {'loss': 0.9102, 'learning_rate': 0.0002, 'epoch': 1.02}
# {'loss': 0.9147, 'learning_rate': 0.0002, 'epoch': 1.02}
# {'loss': 0.9155, 'learning_rate': 0.0002, 'epoch': 1.03}
# {'loss': 0.8617, 'learning_rate': 0.0002, 'epoch': 1.03}
# {'loss': 0.8837, 'learning_rate': 0.0002, 'epoch': 1.03}
# {'loss': 0.9417, 'learning_rate': 0.0002, 'epoch': 1.03}
# {'loss': 0.8845, 'learning_rate': 0.0002, 'epoch': 1.03}
# {'loss': 0.9188, 'learning_rate': 0.0002, 'epoch': 1.03}
# {'loss': 0.8782, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.8955, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.8829, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.9105, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.9019, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.903, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.8273, 'learning_rate': 0.0002, 'epoch': 1.04}
# {'loss': 0.9141, 'learning_rate': 0.0002, 'epoch': 1.05}
# {'loss': 0.9125, 'learning_rate': 0.0002, 'epoch': 1.05}
# {'loss': 0.9337, 'learning_rate': 0.0002, 'epoch': 1.05}
# {'loss': 0.9323, 'learning_rate': 0.0002, 'epoch': 1.05}
# {'loss': 0.8812, 'learning_rate': 0.0002, 'epoch': 1.05}
# {'loss': 0.8859, 'learning_rate': 0.0002, 'epoch': 1.05}
# {'loss': 0.8748, 'learning_rate': 0.0002, 'epoch': 1.06}
# {'loss': 0.8941, 'learning_rate': 0.0002, 'epoch': 1.06}
# {'loss': 0.8614, 'learning_rate': 0.0002, 'epoch': 1.06}
# {'loss': 0.9526, 'learning_rate': 0.0002, 'epoch': 1.06}
# {'loss': 0.8696, 'learning_rate': 0.0002, 'epoch': 1.06}
# {'loss': 0.8887, 'learning_rate': 0.0002, 'epoch': 1.06}
# {'loss': 0.9194, 'learning_rate': 0.0002, 'epoch': 1.07}
# {'loss': 0.9352, 'learning_rate': 0.0002, 'epoch': 1.07}
# {'loss': 0.8757, 'learning_rate': 0.0002, 'epoch': 1.07}
# {'loss': 0.8938, 'learning_rate': 0.0002, 'epoch': 1.07}
# {'loss': 0.908, 'learning_rate': 0.0002, 'epoch': 1.07}
# {'loss': 0.9373, 'learning_rate': 0.0002, 'epoch': 1.07}
# {'loss': 0.8485, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.9009, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.8683, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.9011, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.9058, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.8869, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.934, 'learning_rate': 0.0002, 'epoch': 1.08}
# {'loss': 0.9, 'learning_rate': 0.0002, 'epoch': 1.09}
# {'loss': 0.8651, 'learning_rate': 0.0002, 'epoch': 1.09}
# {'loss': 0.8888, 'learning_rate': 0.0002, 'epoch': 2.0}
# {'loss': 0.8762, 'learning_rate': 0.0002, 'epoch': 2.0}
# {'loss': 0.824, 'learning_rate': 0.0002, 'epoch': 2.0}
# {'loss': 0.9237, 'learning_rate': 0.0002, 'epoch': 2.01}
# {'loss': 0.8732, 'learning_rate': 0.0002, 'epoch': 2.01}
# {'loss': 0.9065, 'learning_rate': 0.0002, 'epoch': 2.01}
# {'loss': 0.8771, 'learning_rate': 0.0002, 'epoch': 2.01}
# {'loss': 0.8554, 'learning_rate': 0.0002, 'epoch': 2.01}
# {'loss': 0.8883, 'learning_rate': 0.0002, 'epoch': 2.01}
# {'loss': 0.8524, 'learning_rate': 0.0002, 'epoch': 2.02}
# {'loss': 0.884, 'learning_rate': 0.0002, 'epoch': 2.02}
# {'loss': 0.9107, 'learning_rate': 0.0002, 'epoch': 2.02}
# {'loss': 0.8807, 'learning_rate': 0.0002, 'epoch': 2.02}
# {'loss': 0.9253, 'learning_rate': 0.0002, 'epoch': 2.02}
# {'loss': 0.906, 'learning_rate': 0.0002, 'epoch': 2.02}
# {'loss': 0.8993, 'learning_rate': 0.0002, 'epoch': 2.03}
# {'loss': 0.8463, 'learning_rate': 0.0002, 'epoch': 2.03}
# {'loss': 0.8866, 'learning_rate': 0.0002, 'epoch': 2.03}
# {'loss': 0.9203, 'learning_rate': 0.0002, 'epoch': 2.03}
# {'loss': 0.8687, 'learning_rate': 0.0002, 'epoch': 2.03}
# {'loss': 0.8623, 'learning_rate': 0.0002, 'epoch': 2.03}
# {'loss': 0.8899, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.9009, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.9078, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.8702, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.8454, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.8327, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.8112, 'learning_rate': 0.0002, 'epoch': 2.04}
# {'loss': 0.9268, 'learning_rate': 0.0002, 'epoch': 2.05}
# {'loss': 0.9053, 'learning_rate': 0.0002, 'epoch': 2.05}
# {'loss': 0.9254, 'learning_rate': 0.0002, 'epoch': 2.05}
# {'loss': 0.8609, 'learning_rate': 0.0002, 'epoch': 2.05}
# {'loss': 0.8366, 'learning_rate': 0.0002, 'epoch': 2.05}
# {'loss': 0.839, 'learning_rate': 0.0002, 'epoch': 2.05}
# {'loss': 0.867, 'learning_rate': 0.0002, 'epoch': 2.06}
# {'loss': 0.89, 'learning_rate': 0.0002, 'epoch': 2.06}
# {'loss': 0.875, 'learning_rate': 0.0002, 'epoch': 2.06}
# {'loss': 0.9478, 'learning_rate': 0.0002, 'epoch': 2.06}
# {'loss': 0.8386, 'learning_rate': 0.0002, 'epoch': 2.06}
# {'loss': 0.7996, 'learning_rate': 0.0002, 'epoch': 2.06}
# {'loss': 0.8885, 'learning_rate': 0.0002, 'epoch': 2.07}
# {'loss': 0.8933, 'learning_rate': 0.0002, 'epoch': 2.07}
# {'loss': 0.8171, 'learning_rate': 0.0002, 'epoch': 2.07}
# {'loss': 0.7994, 'learning_rate': 0.0002, 'epoch': 2.07}
# {'loss': 0.896, 'learning_rate': 0.0002, 'epoch': 2.07}
# {'loss': 0.8945, 'learning_rate': 0.0002, 'epoch': 2.07}
# {'loss': 0.8494, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.8582, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.8731, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.8842, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.8886, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.9055, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.8645, 'learning_rate': 0.0002, 'epoch': 2.08}
# {'loss': 0.9062, 'learning_rate': 0.0002, 'epoch': 2.09}
# {'loss': 0.8823, 'learning_rate': 0.0002, 'epoch': 2.09}
# {'train_runtime': 813.5792, 'train_samples_per_second': 18.437, 'train_steps_per_second': 2.305, 'train_loss': 0.9297997019507668, 'epoch': 2.09}
# TrainOutput(global_step=165, training_loss=0.9297997019507668, metrics={'train_runtime': 813.5792, 'train_samples_per_second': 18.437, 'train_steps_per_second': 2.305, 'train_loss': 0.9297997019507668, 'epoch': 2.09})

# %% [markdown]
# Let's go ahead and save our model!

# %%
trainer.save_model()

# %% [markdown]
# ### Testing Our Model
#
# Now that we've instruct-tuned our model - let's see how it performs!

# %%
if use_flash_attention:
    from utils.llama_patch import unplace_flash_attn_with_attn
    unplace_flash_attn_with_attn()

import torch
from peft import AutoPeftModelForCausalLM
from transformers import AutoTokenizer

args.output_dir = "llama_7_nf4_alpaca_gpt4"

model = AutoPeftModelForCausalLM.from_pretrained(
    args.output_dir,
    low_cpu_mem_usage=True,
    torch_dtype=torch.float16,
    load_in_4bit=True,
)

tokenizer = AutoTokenizer.from_pretrained(args.output_dir)
# Out:
# Reloading llama model, unpatching flash attention
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from random import randrange

sample = dataset[5]

# %%
print(sample)
# Out:
# {'instruction': 'Identify the odd one out.', 'input': 'Twitter, Instagram, Telegram', 'output': 'The odd one out is Telegram. Twitter and Instagram are social media platforms mainly for sharing information, images and videos while Telegram is a cloud-based instant messaging and voice-over-IP service.'}

# %% [markdown]
# First, let's see how our model handles this instruction task!

# %%
instruction_template = f"### Instruction:\n{sample['instruction']}"
input_template = f"### Input:\n{sample['input']}"
generate_response_template = "### Response:"
true_response_template = f"{sample['output']}"

partial_prompt_list = [instruction_template]

if sample["input"]:
    partial_prompt_list.append(input_template)

partial_prompt_list.append(generate_response_template)

generate_prompt = "\n\n".join(partial_prompt_list)

print(f"Prompt:\n{generate_prompt}\n --------")

input_ids = tokenizer(generate_prompt, return_tensors="pt", truncation=True).input_ids.cuda()

outputs = model.generate(input_ids=input_ids, max_new_tokens=100, do_sample=True, top_p=0.9, temperature=0.9)

print(f"Generated Response:\n{tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(generate_prompt):]}\n -----")
print(f"Actual Response:\n{true_response_template}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prompt:
# ### Instruction:
# Identify the odd one out.
#
# ### Input:
# Twitter, Instagram, Telegram
#
# ### Response:
#  --------
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Generated Response:
#
# Telegram.
#  -----
# Actual Response:
# The odd one out is Telegram. Twitter and Instagram are social media platforms mainly for sharing information, images and videos while Telegram is a cloud-based instant messaging and voice-over-IP service.

# %% [markdown]
# Not bad! It provides a decent explanation - and gets the answer "correct"!
#
# Now let's see how the base model would've performed on the same prompt:

# %%
model_id = "NousResearch/Llama-2-7b-hf"

base_llama_2 = AutoModelForCausalLM.from_pretrained(
    model_id,
    low_cpu_mem_usage=True,
    torch_dtype=torch.float16,
    load_in_4bit=True,
)

base_llama_2_tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
instruction_template = f"### Instruction:\n{sample['instruction']}"
input_template = f"### Input:\n{sample['input']}"
generate_response_template = "### Response:"
true_response_template = f"{sample['output']}"

partial_prompt_list = [instruction_template]

if sample["input"]:
    partial_prompt_list.append(input_template)

partial_prompt_list.append(generate_response_template)

generate_prompt = "\n\n".join(partial_prompt_list)

print(f"Prompt:\n{generate_prompt}\n --------")

input_ids = base_llama_2_tokenizer(generate_prompt, return_tensors="pt", truncation=True).input_ids.cuda()

outputs = base_llama_2.generate(input_ids=input_ids, max_new_tokens=100, do_sample=True, top_p=0.9, temperature=0.9)

print(f"Generated Response:\n{base_llama_2_tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(generate_prompt):]}\n -----")
print(f"Actual Response:\n{true_response_template}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prompt:
# ### Instruction:
# Identify the odd one out.
#
# ### Input:
# Twitter, Instagram, Telegram
#
# ### Response:
#  --------
# Generated Response:
#
# Telegram
#
#  -----
# Actual Response:
# The odd one out is Telegram. Twitter and Instagram are social media platforms mainly for sharing information, images and videos while Telegram is a cloud-based instant messaging and voice-over-IP service.

# %% [markdown]
# Well, let's just say - not well!
#
# Even with ~2 epochs of 5k samples, you can already see a massive improvement in the output of our model!

# %% [markdown]
# ### Export and Share
#
# Now that we've done the hard part - let's do the easy part and send this out into the world!

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model = AutoPeftModelForCausalLM.from_pretrained(
    args.output_dir,
    low_cpu_mem_usage=True
)

merged_model = model.merge_and_unload()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
HF_USERNAME = "ai-maker-space"
HF_REPO_NAME = "instruct-tuned-llama-7b-hf-alpaca_gpt4_5_000_samples"

merged_model.push_to_hub(f"{HF_USERNAME}/{HF_REPO_NAME}")
tokenizer.push_to_hub(f"{HF_USERNAME}/{HF_REPO_NAME}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, private, repo_type, exist_ok, space_sdk, space_hardware)
#    2307         try:
# -> 2308             hf_raise_for_status(r)
#    2309         except HTTPError as err:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     302         # as well (request id and/or server error message)
# --> 303         raise HfHubHTTPError(str(e), response=response) from e
#     304
#
# HfHubHTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create (Request ID: Root=1-64eff5c8-3f6f01ed1eaeeaf07bce7d73;6155fa11-5eec-4d98-967b-6052d6854c91)
#
# You don't have the rights to create a model under this namespace
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/ai-maker-space/instruct-tuned-llama-7b-hf-alpaca_gpt4_5_000_samples
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# <ipython-input-29-b2d3f509ba77> in <cell line: 4>()
#       2 HF_REPO_NAME = "instruct-tuned-llama-7b-hf-alpaca_gpt4_5_000_samples"
#       3
# ----> 4 merged_model.push_to_hub(f"{HF_USERNAME}/{HF_REPO_NAME}")
#       5 tokenizer.push_to_hub(f"{HF_USERNAME}/{HF_REPO_NAME}")
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in push_to_hub(self, repo_id, use_temp_dir, commit_message, private, use_auth_token, max_shard_size, create_pr, safe_serialization, **deprecated_kwargs)
#     801             working_dir = repo_id.split("/")[-1]
#     802
# --> 803         repo_id = self._create_repo(
#     804             repo_id, private=private, use_auth_token=use_auth_token, repo_url=repo_url, organization=organization
#     805         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in _create_repo(self, repo_id, private, use_auth_token, repo_url, organization)
#     659                 repo_id = f"{organization}/{repo_id}"
#     660
# --> 661         url = create_repo(repo_id=repo_id, token=use_auth_token, private=private, exist_ok=True)
#     662
#     663         # If the namespace is not there, add it or `upload_file` will complain
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, private, repo_type, exist_ok, space_sdk, space_hardware)
#    2314                 # No write permission on the namespace but repo might already exist
#    2315                 try:
# -> 2316                     self.repo_info(repo_id=repo_id, repo_type=repo_type, token=token)
#    2317                     if repo_type is None or repo_type == REPO_TYPE_MODEL:
#    2318                         return RepoUrl(f"{self.endpoint}/{repo_id}")
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in repo_info(self, repo_id, revision, repo_type, timeout, files_metadata, token)
#    1866         else:
#    1867             raise ValueError("Unsupported repo type.")
# -> 1868         return method(
#    1869             repo_id,
#    1870             revision=revision,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, token)
#    1676             params["blobs"] = True
#    1677         r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 1678         hf_raise_for_status(r)
#    1679         d = r.json()
#    1680         return ModelInfo(**d)
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     291                 " make sure you are authenticated."
#     292             )
# --> 293             raise RepositoryNotFoundError(message, response) from e
#     294
#     295         elif response.status_code == 400:
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-64eff5c8-00c1119a05cf45733c809669;321b7f24-6615-4704-a0d9-3f1c9b66006d)
#
# Repository Not Found for url: https://huggingface.co/api/models/ai-maker-space/instruct-tuned-llama-7b-hf-alpaca_gpt4_5_000_samples.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.

# %%
HF_USERNAME = "PanoEvJ"
HF_REPO_NAME = "instruct-tuned-llama-7b-hf-alpaca_gpt4_5_000_samples"

merged_model.push_to_hub(f"{HF_USERNAME}/{HF_REPO_NAME}")
tokenizer.push_to_hub(f"{HF_USERNAME}/{HF_REPO_NAME}")
# Out:
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.88G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/7.18G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.89G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/PanoEvJ/instruct-tuned-llama-7b-hf-alpaca_gpt4_5_000_samples/commit/778b274ba0b3a15abed21429f209554d27da2a13', commit_message='Upload tokenizer', commit_description='', oid='778b274ba0b3a15abed21429f209554d27da2a13', pr_url=None, pr_revision=None, pr_num=None)
